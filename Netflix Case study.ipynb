# %% [markdown]
# ### Netflix Data Analytics

# %%
import pandas as pd

# %%
#importing the data
data = pd.read_csv("Netflix Movies and TV Shows.csv")

# %% [markdown]
# Basic info of data

# %%
data.head() #top 5 records
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 1  December 23, 2016          2016  TV-MA     93 min
# 2  December 20, 2018          2011      R     78 min
# 3  November 16, 2017          2009  PG-13     80 min
# ...

# %%
data.shape # showing total number of rows and columns in the data set
# Out:
# (7787, 12)

# %%
data.size #total elements
# Out:
# 93444

# %%
data.columns # shows the all columns in data set
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
data.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
data.info() #showing indexes,columns,data types of each column ,memory at once
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7787 entries, 0 to 7786
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7787 non-null   object
#  1   type          7787 non-null   object
#  2   title         7787 non-null   object
#  3   director      5398 non-null   object
#  4   cast          7069 non-null   object
#  5   country       7280 non-null   object
#  6   date_added    7777 non-null   object
#  7   release_year  7787 non-null   int64
#  8   rating        7780 non-null   object
#  9   duration      7787 non-null   object
#  10  listed_in     7787 non-null   object
#  11  description   7787 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 730.2+ KB

# %% [markdown]
#  1. To check Is there any Duplicate Record in this dataset

# %%
data.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 1  December 23, 2016          2016  TV-MA     93 min
# 2  December 20, 2018          2011      R     78 min
# 3  November 16, 2017          2009  PG-13     80 min
# ...

# %%
data[data.duplicated()] # there is no duplicated entires in data
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
data.shape
# Out:
# (7787, 12)

# %% [markdown]
# Check the null values in column

# %%
data.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2389
# cast             718
# country          507
# date_added        10
# release_year       0
# rating             7
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %%
import seaborn as sns

# %%
sns.heatmap(data.isnull()) #showing which columns has max number of null values
# Out:
# <AxesSubplot:>

# %% [markdown]
#  2. For 'Stranger', what is the Show Id and Who is the Director of this show ?

# %%
data[data['title']==('Stranger')]
# Out:
#      show_id     type     title director  \
# 5834   s5835  TV Show  Stranger      NaN
#
#                                                    cast      country  \
# 5834  Seung-woo Cho, Doona Bae, Joon-hyuk Lee, Kyeon...  South Korea
#
#            date_added  release_year rating   duration  \
# 5834  August 16, 2020          2020  TV-MA  2 Seasons
#
#                                               listed_in  \
# 5834  Crime TV Shows, International TV Shows, Korean...
#
#                                             description
# 5834  With the help of a gutsy female detective, a p...

# %% [markdown]
# 3. In which year highest number of the TV Shows & Movies were released ? Show with Bar Graph.

# %%
data.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
data['release_year']=data.release_year.astype(object)

# %%
data.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year    object
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
data['Date_N'] = pd.to_datetime(data['date_added'])

# %%
data.head(100)
# Out:
#    show_id     type           title           director  \
# 0       s1  TV Show              3%                NaN
# 1       s2    Movie            7:19  Jorge Michel Grau
# 2       s3    Movie           23:59       Gilbert Chan
# 3       s4    Movie               9        Shane Acker
# 4       s5    Movie              21     Robert Luketic
# ..     ...      ...             ...                ...
# 95     s96  TV Show        28 Moons                NaN
# 96     s97    Movie  3 Days to Kill                McG
# 97     s98    Movie     3 Deewarein    Nagesh Kukunoor
# 98     s99    Movie   3 Generations        Gaby Dellal
# 99    s100    Movie      3 Heroines     Iman Brotoseno
#
#                                                  cast  \
# 0   João Miguel, Bianca Comparato, Michel Gomes, R...
# 1   Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2   Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3   Elijah Wood, John C. Reilly, Jennifer Connelly...
# ...

# %%
data.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added              object
# release_year            object
# rating                  object
# duration                object
# listed_in               object
# description             object
# Date_N          datetime64[ns]
# dtype: object

# %%
data['Date_N'].dt.year.value_counts() # it counts the occurence of all individual years in date column
# Out:
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2009.0       2
# 2008.0       2
# 2010.0       1
# Name: Date_N, dtype: int64

# %% [markdown]
# Bar Graph

# %%
data['Date_N'].dt.year.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# 4.How many movies & TV shows are in the dataset representation with the bar garph

# %%
data.head(5)
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added release_year rating   duration  \
# 0    August 14, 2020         2020  TV-MA  4 Seasons
# 1  December 23, 2016         2016  TV-MA     93 min
# 2  December 20, 2018         2011      R     78 min
# 3  November 16, 2017         2009  PG-13     80 min
# ...

# %%
data.groupby('type') #grouping all unique items and showing the count

# %%
data.groupby('type').type.count()
# Out:
# type
# Movie      5377
# TV Show    2410
# Name: type, dtype: int64

# %%
#countplot
sns.countplot(data['type'])  # to show the count of all unique values of any column in the form of bar graph
# Out:
# C:\Users\Sandeep\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='type', ylabel='count'>

# %% [markdown]
# 5. All the movies that were released in the year 2019

# %%
data.head(2)
# Out:
#   show_id     type title           director  \
# 0      s1  TV Show    3%                NaN
# 1      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 cast country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#           date_added release_year rating   duration  \
# 0    August 14, 2020         2020  TV-MA  4 Seasons
# 1  December 23, 2016         2016  TV-MA     93 min
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          description     Date_N
# 0  In a future where the elite inhabit an island ... 2020-08-14
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23

# %%
data['year'] = data['Date_N'].dt.year

# %%
data.head(2)
# Out:
#   show_id     type title           director  \
# 0      s1  TV Show    3%                NaN
# 1      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 cast country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#           date_added release_year rating   duration  \
# 0    August 14, 2020         2020  TV-MA  4 Seasons
# 1  December 23, 2016         2016  TV-MA     93 min
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          description     Date_N    year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
#filtering
data[(data['type']== 'Movie') & (data['year']==2018)]
# Out:
#      show_id   type                     title          director  \
# 2         s3  Movie                     23:59      Gilbert Chan
# 17       s18  Movie                    22-Jul   Paul Greengrass
# 19       s20  Movie                       '89               NaN
# 20       s21  Movie      ​​Kuch Bheege Alfaaz              Onir
# 21       s22  Movie              ​Goli Soda 2      Vijay Milton
# ...      ...    ...                       ...               ...
# 7763   s7764  Movie                     Zenda    Avadhoot Gupte
# 7768   s7769  Movie  Zindagi Kitni Haseen Hay     Anjum Shahzad
# 7771   s7772  Movie                      Zion        Floyd Russ
# 7776   s7777  Movie                  Zokkomon  Satyajit Bhatkal
# 7780   s7781  Movie                       Zoo      Shlok Sharma
#
#                                                    cast  \
# 2     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 17    Anders Danielsen Lie, Jon Øigarden, Jonas Stra...
# ...

# %% [markdown]
# 6.Show only the titles of all TV shows that were released in India only

# %%
data.head(2)
# Out:
#   show_id     type title           director  \
# 0      s1  TV Show    3%                NaN
# 1      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 cast country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#           date_added release_year rating   duration  \
# 0    August 14, 2020         2020  TV-MA  4 Seasons
# 1  December 23, 2016         2016  TV-MA     93 min
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          description     Date_N    year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
data[(data['type'] == 'TV Show') & (data['country'] == 'India')]['title']
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                           Akbar Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6248                  The Creative Indians
# 6398    The Golden Years with Javed Akhtar
# 6467                The House That Made Me
# 7292                            Typewriter
# 7703                       Yeh Meri Family
# Name: title, Length: 71, dtype: object

# %% [markdown]
# 7.Show top 10 directors,who gave the highest number of tv shows & movies to netflix

# %%
data['director'].value_counts().head(10)
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Youssef Chahine           12
# Martin Scorsese           12
# Jay Chapman               12
# Steven Spielberg          10
# David Dhawan               9
# Hakan Algül                8
# Name: director, dtype: int64

# %% [markdown]
# Show all the Records, where "Category is Movie and Type is Comedies" or "Country is United Kingdom".

# %%
#filtering with the AND OR operator

# %%
data.head(2)
# Out:
#   show_id     type title           director  \
# 0      s1  TV Show    3%                NaN
# 1      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 cast country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#           date_added release_year rating   duration  \
# 0    August 14, 2020         2020  TV-MA  4 Seasons
# 1  December 23, 2016         2016  TV-MA     93 min
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          description     Date_N    year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
data[(data['type'] == 'Movie') & (data['listed_in']== 'Comedies') | (data['country']=='United Kingdom')]
# Out:
#      show_id     type                   title          director  \
# 19       s20    Movie                     '89               NaN
# 33       s34    Movie            #realityhigh  Fernando Lebrija
# 58       s59  TV Show             100% Hotter               NaN
# 72       s73    Movie                17 Again       Burr Steers
# 82       s83    Movie     2036 Origin Unknown     Hasraf Dulull
# ...      ...      ...                     ...               ...
# 7668   s7669  TV Show  World War II in Colour               NaN
# 7669   s7670  TV Show  World's Busiest Cities               NaN
# 7686   s7687    Movie  XV: Beyond the Tryline  Pierre Deschamps
# 7723   s7724    Movie            You Can Tutu       James Brown
# 7738   s7739  TV Show         Young Wallander               NaN
#
#                                                    cast         country  \
# 19                   Lee Dixon, Ian Wright, Paul Merson  United Kingdom
# ...

# %% [markdown]
#  In how many movies/shows, Tom Cruise was cast ?

# %%
data.head(2)
# Out:
#   show_id     type title           director  \
# 0      s1  TV Show    3%                NaN
# 1      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 cast country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#           date_added release_year rating   duration  \
# 0    August 14, 2020         2020  TV-MA  4 Seasons
# 1  December 23, 2016         2016  TV-MA     93 min
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          description     Date_N    year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
data[data['cast'] == 'Tom Cruise']
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, Date_N, year]
# Index: []

# %%
data_new=data.dropna()

# %%
data_new.head(2)
# Out:
#   show_id   type  title           director  \
# 1      s2  Movie   7:19  Jorge Michel Grau
# 2      s3  Movie  23:59       Gilbert Chan
#
#                                                 cast    country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#           date_added release_year rating duration  \
# 1  December 23, 2016         2016  TV-MA   93 min
# 2  December 20, 2018         2011      R   78 min
#
#                              listed_in  \
# 1         Dramas, International Movies
# 2  Horror Movies, International Movies
#
#                                          description     Date_N    year
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0
# 2  When an army recruit is found dead, his fellow... 2018-12-20  2018.0

# %%
data_new[data_new['cast'].str.contains('Tom Cruise')]
# Out:
#      show_id   type     title              director  \
# 3860   s3861  Movie  Magnolia  Paul Thomas Anderson
# 5070   s5071  Movie  Rain Man        Barry Levinson
#
#                                                    cast        country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5070  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#            date_added release_year rating duration  \
# 3860  January 1, 2020         1999      R  189 min
# 5070     July 1, 2019         1988      R  134 min
#
#                        listed_in  \
# 3860  Dramas, Independent Movies
# 5070      Classic Movies, Dramas
#
#                                             description     Date_N    year
# 3860  Through chance, human action, past history and... 2020-01-01  2020.0
# 5070  A fast-talking yuppie is forced to slow down w... 2019-07-01  2019.0

# %% [markdown]
# 8.What are the different Ratings defined by Netflix ?

# %%
data['rating'].nunique()
# Out:
# 14

# %%
data['rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# 9.How many Movies got the 'TV-14' rating, in Canada ?

# %%
data_new[(data_new['type'] == 'Movie') & (data_new['rating'] == 'TV-14') | (data_new['country']=='Canada')]
# Out:
#      show_id   type                     title            director  \
# 8         s9  Movie                       706       Shravan Kumar
# 15       s16  Movie                    Oct-01      Kunle Afolayan
# 18       s19  Movie                    15-Aug  Swapnaneel Jayakar
# 20       s21  Movie      ​​Kuch Bheege Alfaaz                Onir
# 21       s22  Movie              ​Goli Soda 2        Vijay Milton
# ...      ...    ...                       ...                 ...
# 7763   s7764  Movie                     Zenda      Avadhoot Gupte
# 7764   s7765  Movie                      Zero          Aanand Rai
# 7768   s7769  Movie  Zindagi Kitni Haseen Hay       Anjum Shahzad
# 7769   s7770  Movie  Zindagi Na Milegi Dobara         Zoya Akhtar
# 7783   s7784  Movie                    Zubaan         Mozez Singh
#
#                                                    cast   country  \
# 8     Divya Dutta, Atul Kulkarni, Mohan Agashe, Anup...     India
# ...

# %%
data_new.head(2)
data_new[(data_new['type'] == 'Movie') & (data_new['rating'] == 'TV-14') | (data_new['country']=='Canada')].shape
# Out:
# (1193, 14)

# %% [markdown]
# 10.How many TV Show got the 'R' rating, after year 2018 ?

# %%
data[(data['type']=='TV Show') & (data['rating']=='R') & (data['year']>2018)]
# Out:
#      show_id     type                                title           director  \
# 6435   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    cast country  \
# 6435  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN
#
#           date_added release_year rating  duration listed_in  \
# 6435  April 25, 2019         2015      R  1 Season  TV Shows
#
#                                             description     Date_N    year
# 6435  Trapped at a stagecoach stop as a storm rages ... 2019-04-25  2019.0

# %% [markdown]
# What is the maximum duration of a Movie/Show on Netflix ?

# %%
data['duration'].unique()
# Out:
# array(['4 Seasons', '93 min', '78 min', '80 min', '123 min', '1 Season',
#        '95 min', '119 min', '118 min', '143 min', '103 min', '89 min',
#        '91 min', '149 min', '144 min', '124 min', '87 min', '110 min',
#        '128 min', '117 min', '100 min', '2 Seasons', '84 min', '99 min',
#        '90 min', '102 min', '104 min', '105 min', '56 min', '125 min',
#        '81 min', '97 min', '106 min', '107 min', '109 min', '44 min',
#        '75 min', '101 min', '3 Seasons', '37 min', '113 min', '114 min',
#        '130 min', '94 min', '140 min', '135 min', '82 min', '70 min',
#        '121 min', '92 min', '164 min', '53 min', '83 min', '116 min',
#        '86 min', '120 min', '96 min', '126 min', '129 min', '77 min',
#        '137 min', '148 min', '28 min', '122 min', '176 min', '85 min',
#        '22 min', '68 min', '111 min', '29 min', '142 min', '168 min',
#        '21 min', '59 min', '20 min', '98 min', '108 min', '76 min',
# ...

# %%
data.duration.dtypes
# Out:
# dtype('O')

# %%
data.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added release_year rating   duration  \
# 0    August 14, 2020         2020  TV-MA  4 Seasons
# 1  December 23, 2016         2016  TV-MA     93 min
# 2  December 20, 2018         2011      R     78 min
# 3  November 16, 2017         2009  PG-13     80 min
# ...

# %%
data[['Minutes','Unit']] = data['duration'].str.split(' ',expand=True)

# %%
data.head(2)
# Out:
#   show_id     type title           director  \
# 0      s1  TV Show    3%                NaN
# 1      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 cast country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#           date_added release_year rating   duration  \
# 0    August 14, 2020         2020  TV-MA  4 Seasons
# 1  December 23, 2016         2016  TV-MA     93 min
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          description     Date_N    year  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0
#
#   Minutes     Unit
# 0       4  Seasons
# 1      93      min

# %%
data['Minutes'].max()
# Out:
# '99'

# %% [markdown]
# 11.Which individual country has the Highest No. of TV Shows ?

# %%
data_tvshow =data[data['type'] == 'TV Show']

# %%
data_tvshow.head(2)
# Out:
#   show_id     type title     director  \
# 0      s1  TV Show    3%          NaN
# 5      s6  TV Show    46  Serdar Akar
#
#                                                 cast country       date_added  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...  Turkey     July 1, 2017
#
#   release_year rating   duration  \
# 0         2020  TV-MA  4 Seasons
# 5         2016  TV-MA   1 Season
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 5    International TV Shows, TV Dramas, TV Mysteries
#
#                                          description     Date_N    year  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 5  A genetics professor experiments with a treatm... 2017-07-01  2017.0
#
#   Minutes     Unit
# 0       4  Seasons
# 5       1   Season

# %%
data_tvshow.country.value_counts().head(10)
# Out:
# United States     705
# United Kingdom    204
# Japan             157
# South Korea       147
# India              71
# Taiwan             68
# Canada             59
# Australia          46
# France             46
# Spain              45
# Name: country, dtype: int64

# %% [markdown]
# How can we sort the dataset by Year ?

# %%
data.sort_values(by= 'year')
# Out:
#      show_id     type                         title              director  \
# 1765   s1766  TV Show               Dinner for Five                   NaN
# 7113   s7114    Movie          To and From New York  Sorin Dan Mihalcescu
# 3248   s3249    Movie       Just Another Love Story          Ole Bornedal
# 5765   s5766    Movie                      Splatter             Joe Dante
# 3840   s3841    Movie   Mad Ron's Prevues from Hell            Jim Monaco
# ...      ...      ...                           ...                   ...
# 3374   s3375  TV Show                      Kikoriki                   NaN
# 3492   s3493  TV Show           La Familia P. Luche                   NaN
# 3946   s3947  TV Show                         Maron                   NaN
# 5137   s5138  TV Show                  Red vs. Blue                   NaN
# 6065   s6066  TV Show  The Adventures of Figaro Pho                   NaN
#
#                                                    cast        country  \
# ...

# %%
data.sort_values(by= 'year',ascending=False).head(2)
# Out:
#      show_id   type             title            director  \
# 7351   s7352  Movie           Unknown  Jaume Collet-Serra
# 2013   s2014  Movie  Enter the Dragon       Robert Clouse
#
#                                                    cast  \
# 7351  Liam Neeson, Diane Kruger, January Jones, Aida...
# 2013  Bruce Lee, John Saxon, Jim Kelly, Ahna Capri, ...
#
#                                              country       date_added  \
# 7351  United Kingdom, Germany, France, United States  January 1, 2021
# 2013                        Hong Kong, United States  January 1, 2021
#
#      release_year rating duration                           listed_in  \
# 7351         2011  PG-13  113 min       Action & Adventure, Thrillers
# 2013         1973      R  103 min  Action & Adventure, Classic Movies
#
#                                             description     Date_N    year  \
# 7351  Liam Neeson stars as a man who regains conscio... 2021-01-01  2021.0
# ...

# %% [markdown]
# 12.Find all the instances where : Category is 'Movie' and Type is 'Dramas' or Category is 'TV Show' & Type is 'Kids' TV'.

# %%
data.head(2)
# Out:
#   show_id     type title           director  \
# 0      s1  TV Show    3%                NaN
# 1      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 cast country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#           date_added release_year rating   duration  \
# 0    August 14, 2020         2020  TV-MA  4 Seasons
# 1  December 23, 2016         2016  TV-MA     93 min
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          description     Date_N    year  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0
#
#   Minutes     Unit
# 0       4  Seasons
# 1      93      min

# %%
data['type']== 'Movie') & (data['listed_in']== 'Dramas')

# %%
data[(data['type']== 'Movie') & (data['listed_in']== 'Dramas')]
# Out:
#      show_id   type                       title           director  \
# 4         s5  Movie                          21     Robert Luketic
# 7         s8  Movie                         187     Kevin Reynolds
# 170     s171  Movie                A Family Man      Mark Williams
# 232     s233  Movie  A Stoning in Fulham County      Larry Elikann
# 295     s296  Movie          Across Grace Alley      Ralph Macchio
# ...      ...    ...                         ...                ...
# 7415   s7416  Movie                      Victor  Brandon Dickerson
# 7420   s7421  Movie                     Villain   Philip Barantini
# 7447   s7448  Movie                         VS.           Ed Lilly
# 7463   s7464  Movie                   Wakefield      Robin Swicord
# 7478   s7479  Movie                   War Horse   Steven Spielberg
#
#                                                    cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %%
data[(data['type']== 'TV Show') & (data['listed_in']== "Kids' TV")]
# Out:
#      show_id     type              title             director  \
# 111     s112  TV Show            44 Cats                  NaN
# 276     s277  TV Show       Abby Hatcher          Kyran Kelly
# 434     s435  TV Show        Alphablocks                  NaN
# 598     s599  TV Show  Ask the StoryBots                  NaN
# 706     s707  TV Show         Bal Ganesh  Vijay S. Bhanushali
# ...      ...      ...                ...                  ...
# 7666   s7667  TV Show      World of Winx       Iginio Straffi
# 7715   s7716  TV Show               Yoko                  NaN
# 7717   s7718  TV Show                YOM                  NaN
# 7756   s7757  TV Show                 Z4                  NaN
# 7759   s7760  TV Show          Zak Storm                  NaN
#
#                                                    cast  \
# 111   Sarah Natochenny, Suzy Myers, Simona Berman, E...
# 276   Macy Drouin, Wyatt White, Paul Sun-Hyung Lee, ...
# ...

# %%
(data['type']== 'Movie') & (data['listed_in']== 'Dramas') | (data['type']== 'TV Show') & (data['listed_in']== "Kids' TV")

# %%
data[(data['type']== 'Movie') & (data['listed_in']== 'Dramas') | (data['type']== 'TV Show') & (data['listed_in']== "Kids' TV")]
# Out:
#      show_id     type                       title        director  \
# 4         s5    Movie                          21  Robert Luketic
# 7         s8    Movie                         187  Kevin Reynolds
# 111     s112  TV Show                     44 Cats             NaN
# 170     s171    Movie                A Family Man   Mark Williams
# 232     s233    Movie  A Stoning in Fulham County   Larry Elikann
# ...      ...      ...                         ...             ...
# 7666   s7667  TV Show               World of Winx  Iginio Straffi
# 7715   s7716  TV Show                        Yoko             NaN
# 7717   s7718  TV Show                         YOM             NaN
# 7756   s7757  TV Show                          Z4             NaN
# 7759   s7760  TV Show                   Zak Storm             NaN
#
#                                                    cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 7     Samuel L. Jackson, John Heard, Kelly Rowan, Cl...
# ...
